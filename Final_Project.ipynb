# %% [markdown]
# <a href="https://colab.research.google.com/github/Octa-p/data_viz_2022/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path = '/content/drive/My Drive/DataViz22_data'
data_cases = pd.read_csv(os.path.join(path, 'confirmed-cases.csv'))
data_cases1 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-120864.csv'))
data_cases2 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-271064.csv'))
data_cases3 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-280265.csv'))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # ข้อมูลจำนวนผู้เชื้อช่วงที่ 1

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# # ข้อมูลจำนวนผู้เชื้อช่วงที่ 2

# %%
data_cases1
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# # ข้อมูลจำนวนผู้เชื้อช่วงที่ 3

# %%
data_cases2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# ...

# %% [markdown]
# # ข้อมูลจำนวนผู้เชื้อช่วงที่ 4

# %%
data_cases3
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357077  3226694     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357078  3226695     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357079  3226696     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357080  3226697     15/3/2022     14/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# # เตรียมข้อมูล

# %% [markdown]
# ## ข้อมูลจำนวนผู้เชื้อช่วงที่ 1

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *   Notified date
# *   sex
# *   age
# *   Unit
# *   nationality
# *   province_of_isolation
# *   risk
# *   province_of_onset
# *   district_of_onset

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
case = data_cases.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'}) #แทนด้วยคำว่า ไม่มีข้อมูล ได้เนื่องจากในตารางมีค่าว่าง และในคอลัมป์ไม่มีค่าเป็นตัวเลขจึงใช้ค่า string ในการแทนที่ได้

# %%
case
# Out:
#            No. announce_date Notified date   sex   age Unit  nationality  \
# 0            1     12/1/2020   ไม่มีข้อมูล  หญิง  61.0   ปี        China
# 1            2     17/1/2020   ไม่มีข้อมูล  หญิง  74.0   ปี        China
# 2            3     22/1/2020   ไม่มีข้อมูล  หญิง  73.0   ปี     Thailand
# 3            4     22/1/2020   ไม่มีข้อมูล   ชาย  68.0   ปี        China
# 4            5     24/1/2020   ไม่มีข้อมูล  หญิง  66.0   ปี        China
# ...        ...           ...           ...   ...   ...  ...          ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี  ไม่มีข้อมูล
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี     Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี     Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี     Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี     Thailand
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# ### แทนค่า missing ของ age ด้วย mean()

# %%
mean_age = case[['age']].mean() # เนื่องจากค่า age เป็นตัวเลขจึงจะต้องแทนค่าด้วยค่าเฉลี่ยของตัวเลขนั้นๆในช่องว่าง
mean_age
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Series([], dtype: float64)

# %%
case[['age']] = case[['age']].fillna(mean_age)

# %%
case.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                       True
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลของจำนวนติดเชื้อช่วงที่ 1 ไม่มีค่า missing แล้ว

# %% [markdown]
# ## dropna

# %%
casedrop = pd.read_csv(os.path.join(path, 'confirmed-cases.csv'))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
casedrop_clean = casedrop.dropna() 
casedrop_clean
# Out:
#            No. announce_date Notified date   sex   age Unit     nationality  \
# 47          48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 124        125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 161        162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 186        187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...        ...           ...           ...   ...   ...  ...             ...
# 839391  839392     12/8/2021     11/8/2021  หญิง  83.0   ปี        Thailand
# 839392  839393     12/8/2021     11/8/2021   ชาย  66.0   ปี        Thailand
# 839393  839394     12/8/2021     11/8/2021  หญิง  43.0   ปี        Thailand
# 839394  839395     12/8/2021     11/8/2021  หญิง  74.0   ปี        Thailand
# 839395  839396     12/8/2021     11/8/2021   ชาย  29.0   ปี        Thailand
#
#        province_of_isolation  \
# ...

# %%
casedrop_clean.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ## ข้อมูลจำนวนผู้เชื้อช่วงที่ 2

# %%
data_cases1.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *   sex
# *   age
# *   Unit
# *   nationality
# *   province_of_onset
# *   district_of_onset

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
case1 = data_cases1.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})

# %%
case1
# Out:
#              No. announce_date Notified date   sex   age Unit  nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี     Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี     Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี     Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี     Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี     Thailand
# ...          ...           ...           ...   ...   ...  ...          ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี  ไม่มีข้อมูล
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี  ไม่มีข้อมูล
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี  ไม่มีข้อมูล
#
# ...

# %% [markdown]
# ### แทนค่า missing ของ age ด้วย mean()

# %%
mean_age1 = case1[['age']].mean()

# %%
case1[['age']] = case1[['age']].fillna(mean_age1)

# %%
case1.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลของจำนวนติดเชื้อช่วงที่ 2 ไม่มีค่า missing แล้ว

# %% [markdown]
# ## dropna

# %%
casedrop2 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-120864.csv'))

# %%
casedrop2_clean = casedrop2.dropna() 
casedrop2_clean
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 249       817239     12/8/2021     11/8/2021   ชาย  48.0   ปี    Thailand
# 250       817240     12/8/2021     11/8/2021  หญิง  19.0   ปี    Thailand
# 251       817241     12/8/2021     11/8/2021  หญิง  37.0   ปี    Thailand
# 252       817242     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 253       817243     12/8/2021     11/8/2021   ชาย  60.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1041962  1858952    25/10/2021    24/10/2021   ชาย  67.0   ปี    Thailand
# 1041963  1858953    25/10/2021    24/10/2021  หญิง  39.0   ปี    Thailand
# 1041964  1858954    25/10/2021    24/10/2021   ชาย  80.0   ปี    Thailand
# 1041965  1858955    25/10/2021    24/10/2021  หญิง  67.0   ปี    Thailand
# 1041966  1858956    25/10/2021    24/10/2021  หญิง  53.0   ปี    Thailand
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## ข้อมูลจำนวนผู้เชื้อช่วงที่ 3

# %%
data_cases2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# Unnamed: 11               True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *   sex
# *   age
# *   Unit
# *   nationality
# *   province_of_isolation
# *   risk
# *   province_of_onset
# *   district_of_onset
# *   Unnamed:11

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
case2 = data_cases2.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})
case2
# Out:
#              No. announce_date Notified date   sex   age         Unit  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0           ปี
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0           ปี
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0           ปี
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0           ปี
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0           ปี
# ...          ...           ...           ...   ...   ...          ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
#
#          nationality province_of_isolation  \
# 0           Thailand                 ลำปาง
# ...

# %% [markdown]
# ### แทนค่า missing ของ age ด้วย mean()

# %%
mean_age2 = case2[['age']].mean() 
mean_age2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Series([], dtype: float64)

# %%
case2[['age']] = case2[['age']].fillna(mean_age2)

# %%
case2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                       True
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# Unnamed: 11               True
# dtype: bool

# %% [markdown]
# ตัด column Unnamed: 11 ออกเนื่องจากไม่ทราบว่าเป็นข้อมูลเกี่ยวกับอะไรและเป็น column ที่ไม่มีความเกี่ยวข้องกัน

# %%
case2.drop(['Unnamed: 11'], axis=1, inplace=True)
case2
# Out:
#              No. announce_date Notified date   sex   age         Unit  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0           ปี
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0           ปี
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0           ปี
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0           ปี
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0           ปี
# ...          ...           ...           ...   ...   ...          ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  ไม่มีข้อมูล
#
#          nationality province_of_isolation  \
# 0           Thailand                 ลำปาง
# ...

# %%
case2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                       True
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลของจำนวนติดเชื้อช่วงที่ 3 ไม่มีค่า missing แล้ว

# %% [markdown]
# ## dropna

# %%
casedrop3 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-271064.csv'))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
casedrop3.drop(['Unnamed: 11'], axis=1, inplace=True)
casedrop3
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# ...

# %%
casedrop3_clean = casedrop3.dropna() 
casedrop3_clean
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010370  2869528     27/2/2022     26/2/2022  หญิง   7.0   ปี    Thailand
# 1010371  2869529     27/2/2022     26/2/2022   ชาย  38.0   ปี      French
# 1010372  2869530     27/2/2022     26/2/2022  หญิง  58.0   ปี      French
# 1010373  2869531     27/2/2022     26/2/2022   ชาย  66.0   ปี    Thailand
# 1010374  2869532     27/2/2022     26/2/2022   ชาย  64.0   ปี    Thailand
#
#         province_of_isolation                                           risk  \
# ...

# %% [markdown]
# ## ข้อมูลจำนวนผู้เชื้อช่วงที่ 4

# %%
data_cases3.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *   sex
# *   age
# *   Unit
# *   nationality
# *   risk
# *   province_of_onset
# *   district_of_onset

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
case3 = data_cases3.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})
case3
# Out:
#             No. announce_date Notified date   sex   age         Unit  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0           ปี
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0           ปี
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0           ปี
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0           ปี
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0           ปี
# ...         ...           ...           ...   ...   ...          ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย   NaN  ไม่มีข้อมูล
# 357077  3226694     15/3/2022     14/3/2022   ชาย   NaN  ไม่มีข้อมูล
# 357078  3226695     15/3/2022     14/3/2022   ชาย   NaN  ไม่มีข้อมูล
# 357079  3226696     15/3/2022     14/3/2022   ชาย   NaN  ไม่มีข้อมูล
# 357080  3226697     15/3/2022     14/3/2022  หญิง   NaN  ไม่มีข้อมูล
#
#         nationality province_of_isolation  \
# 0          Thailand                 พะเยา
# 1          Thailand                 พะเยา
# ...

# %% [markdown]
# ### แทนค่า missing ของ age ด้วย mean()

# %%
mean_age3 = case3[['age']].mean() 
mean_age3
# Out:
# age    36.943725
# dtype: float64

# %%
case3[['age']] = case3[['age']].fillna(mean_age3)

# %%
case3.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลของจำนวนติดเชื้อช่วงที่ 3 ไม่มีค่า missing แล้ว

# %% [markdown]
# ## dropna

# %%
casedrop4 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-280265.csv'))

# %%
casedrop4_clean = casedrop4.dropna() 
casedrop4_clean
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 357022  3226639     15/3/2022     14/3/2022  หญิง  66.0   ปี    Thailand
# 357023  3226640     15/3/2022     14/3/2022  หญิง  49.0   ปี    Thailand
# 357024  3226641     15/3/2022     14/3/2022  หญิง  19.0   ปี    Thailand
# 357025  3226642     15/3/2022     14/3/2022   ชาย  66.0   ปี    Thailand
# 357026  3226643     15/3/2022     14/3/2022   ชาย  46.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## รวมตาราง

# %% [markdown]
# ### รวมตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 1 และ ข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 2

# %%
case12= pd.concat([case, case1],axis=0) #vertical_concat
case12
# Out:
#              No. announce_date Notified date   sex   age Unit  nationality  \
# 0              1     12/1/2020   ไม่มีข้อมูล  หญิง  61.0   ปี        China
# 1              2     17/1/2020   ไม่มีข้อมูล  หญิง  74.0   ปี        China
# 2              3     22/1/2020   ไม่มีข้อมูล  หญิง  73.0   ปี     Thailand
# 3              4     22/1/2020   ไม่มีข้อมูล   ชาย  68.0   ปี        China
# 4              5     24/1/2020   ไม่มีข้อมูล  หญิง  66.0   ปี        China
# ...          ...           ...           ...   ...   ...  ...          ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี  ไม่มีข้อมูล
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี  ไม่มีข้อมูล
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี  ไม่มีข้อมูล
#
#         province_of_isolation                              risk  \
# ...

# %% [markdown]
# ### รวมตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 3 และ ข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 4

# %%
case34= pd.concat([case2, case3],axis=0) #vertical_concat
case34
# Out:
#             No. announce_date Notified date   sex        age         Unit  \
# 0       1859158    26/10/2021    25/10/2021   ชาย       20.0           ปี
# 1       1859159    26/10/2021    25/10/2021  หญิง       42.0           ปี
# 2       1859160    26/10/2021    25/10/2021  หญิง       33.0           ปี
# 3       1859161    26/10/2021    25/10/2021  หญิง       52.0           ปี
# 4       1859162    26/10/2021    25/10/2021  หญิง       84.0           ปี
# ...         ...           ...           ...   ...        ...          ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357077  3226694     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357078  3226695     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357079  3226696     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357080  3226697     15/3/2022     14/3/2022  หญิง  36.943725  ไม่มีข้อมูล
#
#         nationality province_of_isolation  \
# ...

# %%
case234= pd.concat([case1,case2, case3],axis=0) #vertical_concat
case234
# Out:
#             No. announce_date Notified date   sex        age         Unit  \
# 0        816990     12/8/2021     11/8/2021   ชาย        7.0           ปี
# 1        816991     12/8/2021     11/8/2021   ชาย        1.0           ปี
# 2        816992     12/8/2021     11/8/2021   ชาย       35.0           ปี
# 3        816993     12/8/2021     11/8/2021  หญิง       33.0           ปี
# 4        816994     12/8/2021     11/8/2021  หญิง       14.0           ปี
# ...         ...           ...           ...   ...        ...          ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357077  3226694     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357078  3226695     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357079  3226696     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357080  3226697     15/3/2022     14/3/2022  หญิง  36.943725  ไม่มีข้อมูล
#
#         nationality province_of_isolation  \
# ...

# %% [markdown]
# ### เอาตาราง case12 และ case34 มารวมกัน

# %%
case1234= pd.concat([case12, case34],axis=0) #vertical_concat
case1234
# Out:
#             No. announce_date Notified date   sex        age         Unit  \
# 0             1     12/1/2020   ไม่มีข้อมูล  หญิง       61.0           ปี
# 1             2     17/1/2020   ไม่มีข้อมูล  หญิง       74.0           ปี
# 2             3     22/1/2020   ไม่มีข้อมูล  หญิง       73.0           ปี
# 3             4     22/1/2020   ไม่มีข้อมูล   ชาย       68.0           ปี
# 4             5     24/1/2020   ไม่มีข้อมูล  หญิง       66.0           ปี
# ...         ...           ...           ...   ...        ...          ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357077  3226694     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357078  3226695     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357079  3226696     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357080  3226697     15/3/2022     14/3/2022  หญิง  36.943725  ไม่มีข้อมูล
#
#         nationality province_of_isolation                              risk  \
# ...

# %% [markdown]
# ## รวมตารางที่ drop

# %%
casedrop1234= pd.concat([casedrop,casedrop2, casedrop3, casedrop4],axis=0) #vertical_concat
casedrop1234
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357077  3226694     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357078  3226695     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357079  3226696     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357080  3226697     15/3/2022     14/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %%
casedrop1234_clean = casedrop1234.dropna() 
casedrop1234_clean
# Out:
#             No. announce_date Notified date   sex   age Unit     nationality  \
# 47           48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 124         125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 161         162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 181         182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 186         187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...         ...           ...           ...   ...   ...  ...             ...
# 357022  3226639     15/3/2022     14/3/2022  หญิง  66.0   ปี        Thailand
# 357023  3226640     15/3/2022     14/3/2022  หญิง  49.0   ปี        Thailand
# 357024  3226641     15/3/2022     14/3/2022  หญิง  19.0   ปี        Thailand
# 357025  3226642     15/3/2022     14/3/2022   ชาย  66.0   ปี        Thailand
# 357026  3226643     15/3/2022     14/3/2022   ชาย  46.0   ปี        Thailand
#
# ...

# %% [markdown]
# # ข้อมูลจังหวัดแต่ละภูมิภาค

# %%
import pandas as pd

# %%
data_province = {'province': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            '6 ภูมิภาค (ภูมิศาสตร์)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']
}

# %%
province_df = pd.DataFrame.from_dict(data_province) #คำสั่งสร้างตาราง Dataframe
province_df
# Out:
#       province 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# # ข้อมูลรายชื่อห้องปฏิบัติการเครือข่ายตรวจโควิด-19

# %%
lab = pd.read_csv('labscovid19_update080365.csv', encoding="TIS-620") # TIS-620 คือ Decoding ที่เราใช้อ่านจาก file.csv แล้วนำค่ากลับมา Encodingเป็น UTF-8-sig เพื่อให้ตัว microsoft excel ในเครื่องเราที่มีdefault ในการอ่านค่าเป็น utf-8 อ่านได้ 
lab
# Out:
#                                         orgth  \
# 0     ศูนย์วิทยาศาสตร์การแพทย์ที่ 1 เชียงใหม่
# 1    ศูนย์วิทยาศาสตร์การแพทย์ที่ 1/1 เชียงราย
# 2     สำนักงานป้องกันควบคุมโรคที่ 1 เชียงใหม่
# 3                           โรงพยาบาลนครพิงค์
# 4                              โรงพยาบาลลำปาง
# ..                                        ...
# 508           งานอณูชีววิทยา โรงพยาบาลราชวิถี
# 509           งานจุลชีววิทยา โรงพยาบาลราชวิถี
# 510                        โรงพยาบาลประโคนชัย
# 511     กรุงเทพพยาธิ-แลป คลินิกเทคนิคการแพทย์
# 512            เอ็นเฮลท์ คลินิกเทคนิคการแพทย์
#
#                                                  orgen  \
# 0        Regional Medical Sciences Center 1 Chiang Mai
# 1      Regional Medical Sciences Center 1/1 Chiang Rai
# 2    The Office of Disease Prevention and Control 1...
# 3                                  Nakornping Hospital
# 4                                     Lampang Hospital
# ..                                                 ...
# ...

# %% [markdown]
# จากในตารางมีข้อมูลดังนี้
#
# *   orgth = ชื่อห้องปฏิบัติการภาษาไทย
# *   orgen = ชื่อห้องปฏิบัติการภาษาอังกฤษ
# *   telephone = หมายเลขโทรศัพท์
# *   address = ที่อยู่ของห้องปฏิบัติการ
# *   website = เว็บไซต์
# *   healtharea = เขต
# *   agency = หน่วยงาน
# *   province = จังหวัด
# *   district = อำเภอ
# *   area = บริเวณพื้นที่
# *   npsts = สถานะ (NPS+TS = การตรวจด้วยตัวอย่างป้ายหลังโพรงจมูก และป้ายลำคอ)
# *   pooledsaliva = สถานะ (การตรวจด้วยตัวอย่างน้ำลาย)
# *   pooledswab = สถานะ (การตรวจด้วยตัวอย่างในโพรงจมูก

# %%
lab.isnull().any()
# Out:
# orgth           False
# orgen            True
# telephone        True
# address          True
# website          True
# healtharea      False
# agency          False
# province        False
# district         True
# area            False
# npsts           False
# pooledsaliva     True
# pooledswab       True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *  orgen
# *  telephone
# *  address
# *  website
# *  district
# *  pooledsaliva
# *  pooledswab

# %% [markdown]
# ## แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
lab_clean = lab.fillna(value={'orgen':'ไม่ระบุ','telephone':'ไม่ระบุ','address':'ไม่ระบุ','district':'ไม่ระบุ','pooledsaliva':'ไม่ระบุ','pooledswab':'ไม่ระบุ'})
lab_clean
# Out:
#                                         orgth  \
# 0     ศูนย์วิทยาศาสตร์การแพทย์ที่ 1 เชียงใหม่
# 1    ศูนย์วิทยาศาสตร์การแพทย์ที่ 1/1 เชียงราย
# 2     สำนักงานป้องกันควบคุมโรคที่ 1 เชียงใหม่
# 3                           โรงพยาบาลนครพิงค์
# 4                              โรงพยาบาลลำปาง
# ..                                        ...
# 508           งานอณูชีววิทยา โรงพยาบาลราชวิถี
# 509           งานจุลชีววิทยา โรงพยาบาลราชวิถี
# 510                        โรงพยาบาลประโคนชัย
# 511     กรุงเทพพยาธิ-แลป คลินิกเทคนิคการแพทย์
# 512            เอ็นเฮลท์ คลินิกเทคนิคการแพทย์
#
#                                                  orgen  \
# 0        Regional Medical Sciences Center 1 Chiang Mai
# 1      Regional Medical Sciences Center 1/1 Chiang Rai
# 2    The Office of Disease Prevention and Control 1...
# 3                                  Nakornping Hospital
# 4                                     Lampang Hospital
# ..                                                 ...
# ...

# %%
lab_clean.isnull().any()
# Out:
# orgth           False
# orgen           False
# telephone       False
# address         False
# website          True
# healtharea      False
# agency          False
# province        False
# district        False
# area            False
# npsts           False
# pooledsaliva    False
# pooledswab      False
# dtype: bool

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลรายชื่อห้องปฏิบัติการเครือข่ายตรวจโควิด-19 ไม่มีค่า missing แล้ว

# %% [markdown]
# ## dropna

# %%
labdrop = pd.read_csv('labscovid19_update080365.csv', encoding="TIS-620") # TIS-620 คือ Decoding ที่เราใช้อ่านจาก file.csv แล้วนำค่ากลับมา Encodingเป็น UTF-8-sig เพื่อให้ตัว microsoft excel ในเครื่องเราที่มีdefault ในการอ่านค่าเป็น utf-8 อ่านได้

# %%
labdrop_clean = labdrop.dropna()
labdrop_clean
# Out:
#                                         orgth  \
# 0     ศูนย์วิทยาศาสตร์การแพทย์ที่ 1 เชียงใหม่
# 1    ศูนย์วิทยาศาสตร์การแพทย์ที่ 1/1 เชียงราย
# 3                           โรงพยาบาลนครพิงค์
# 4                              โรงพยาบาลลำปาง
# 7             โรงพยาบาลเชียงรายประชานุเคราะห์
# ..                                        ...
# 310                   โรงพยาบาลสหวิทยาการมะลิ
# 312                             โรงพยาบาลกลาง
# 314                          โรงพยาบาลวิภาราม
# 315                         โรงพยาบาลเมดพาร์ค
# 320                      โรงพยาบาลไทยนครินทร์
#
#                                                orgen  \
# 0      Regional Medical Sciences Center 1 Chiang Mai
# 1    Regional Medical Sciences Center 1/1 Chiang Rai
# 3                                Nakornping Hospital
# 4                                   Lampang Hospital
# 7                   Chiang Rai Prachanukroh Hospital
# ..                                               ...
# ...

# %% [markdown]
# ### case+province

# %%
case_prodp = casedrop1234_clean.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
case_prodp
# Out:
#              No. announce_date Notified date   sex   age Unit     nationality  \
# 0             48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 1            125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 2            162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 3            182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 4            187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...          ...           ...           ...   ...   ...  ...             ...
# 2361302  3226639     15/3/2022     14/3/2022  หญิง  66.0   ปี        Thailand
# 2361303  3226640     15/3/2022     14/3/2022  หญิง  49.0   ปี        Thailand
# 2361304  3226641     15/3/2022     14/3/2022  หญิง  19.0   ปี        Thailand
# 2361305  3226642     15/3/2022     14/3/2022   ชาย  66.0   ปี        Thailand
# 2361306  3226643     15/3/2022     14/3/2022   ชาย  46.0   ปี        Thailand
#
# ...

# %%
data_ch = case_prodp[['announce_date','age','risk','6 ภูมิภาค (ภูมิศาสตร์)','province_of_onset']]
data_ch
# Out:
#         announce_date   age                                         risk  \
# 0            6/3/2020  43.0             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1            6/3/2021  55.0                          Cluster ตลาดพรพัฒน์
# 2           17/3/2020  14.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3           18/3/2020  33.0                                      สนามมวย
# 4           18/3/2020  36.0                                      สนามมวย
# ...               ...   ...                                          ...
# 2361302     15/3/2022  66.0                                        อื่นๆ
# 2361303     15/3/2022  49.0                                        อื่นๆ
# 2361304     15/3/2022  19.0                                        อื่นๆ
# 2361305     15/3/2022  66.0                                        อื่นๆ
# 2361306     15/3/2022  46.0                                        อื่นๆ
#
#         6 ภูมิภาค (ภูมิศาสตร์) province_of_onset
# ...

# %%
case_pro_labdp=  data_ch.merge(labdrop_clean,how='left',left_on='province_of_onset',right_on = 'province') 
case_pro_labdp
# Out:
#          announce_date   age                              risk  \
# 0             6/3/2020  43.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1             6/3/2020  43.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2             6/3/2020  43.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3             6/3/2020  43.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4             6/3/2020  43.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                ...   ...                               ...
# 15752025     15/3/2022  46.0                             อื่นๆ
# 15752026     15/3/2022  46.0                             อื่นๆ
# 15752027     15/3/2022  46.0                             อื่นๆ
# 15752028     15/3/2022  46.0                             อื่นๆ
# 15752029     15/3/2022  46.0                             อื่นๆ
#
#          6 ภูมิภาค (ภูมิศาสตร์) province_of_onset  \
# 0                          กลาง     กรุงเทพมหานคร
# 1                          กลาง     กรุงเทพมหานคร
# 2                          กลาง     กรุงเทพมหานคร
# ...

# %%
all_cities = set(case_pro_labdp['province_of_onset'])
all_cities
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชอนแก่น',
#  'ชัยนาถ',
#  'ชัยนาท',
#  'ชัยบาดาล',
#  'ชัยภูมิ',
#  'ชัยภูมิ\xa0',
# ...

# %%
case_pro_labdp['province_of_onset'].replace({'ขานุวรลักษณ์บุรี':'กำแพงเพชร','กรุงเทพมหานคร.':'กรุงเทพมหานคร','กำแพงเพชร\xa0':'กำแพงเพชร','ชลบุรี\xa0':'ชลบุรี','ตราด\xa0':'ตราด','นครปฐม\xa0':'นครปฐม','นครนายก':'นครยายก','นครราชศรีมา':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา','นครสวรรค์\xa0':'นครสวรรค์','บุรีรัมย์\xa0':'บุรีรัมย์','ปทุมธานี\xa0':'ปทุมธานี','พิษณุโลก\xa0':'พิษณุโลก','ลพบุรี\xa0':'ลพบุรี','สมุทรปราการ\xa0':'สมุทรปราการ','ปัตตนรี':'ปัตตานี','สมุทสาคร':'สมุทรสาคร','สุราษฏร์ธานี':'สุราษฎร์ธานี','สมุทiสาคร':'สมุทรสาคร','สุโขทัย\xa0':'สุโขทัย','อุดรธานี\xa0':'อุดรธานี','อุบลราชธานี\xa0':'อุบลราชธานี','เพชรบูรณ์\xa0':'เพชรบูรณ์','อยุทธยา':'อยุธยา','เชิงเทรา':'ฉะเชิงเทรา','พระนครศรีอยุธยา':'อยุธยา'},inplace=True)

# %%
set(case_pro_labdp['province_of_onset'])
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชอนแก่น',
#  'ชัยนาถ',
#  'ชัยนาท',
#  'ชัยบาดาล',
#  'ชัยภูมิ',
#  'ชัยภูมิ\xa0',
#  'ชุมพร',
#  'ชุุมพร',
#  'ชุุุมพร',
#  'ดอนมดแดง',
#  'ดินแดง',
#  'ตรัง',
#  'ตรััง',
# ...

# %%
case_pro=  case1234.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
case_pro
# Out:
#              No. announce_date Notified date   sex        age         Unit  \
# 0              1     12/1/2020   ไม่มีข้อมูล  หญิง       61.0           ปี
# 1              2     17/1/2020   ไม่มีข้อมูล  หญิง       74.0           ปี
# 2              3     22/1/2020   ไม่มีข้อมูล  หญิง       73.0           ปี
# 3              4     22/1/2020   ไม่มีข้อมูล   ชาย       68.0           ปี
# 4              5     24/1/2020   ไม่มีข้อมูล  หญิง       66.0           ปี
# ...          ...           ...           ...   ...        ...          ...
# 3249474  3226693     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 3249475  3226694     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 3249476  3226695     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 3249477  3226696     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 3249478  3226697     15/3/2022     14/3/2022  หญิง  36.943725  ไม่มีข้อมูล
#
# ...

# %%
case_pro2=  case234.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
case_pro2
# Out:
#              No. announce_date Notified date   sex        age         Unit  \
# 0         816990     12/8/2021     11/8/2021   ชาย        7.0           ปี
# 1         816991     12/8/2021     11/8/2021   ชาย        1.0           ปี
# 2         816992     12/8/2021     11/8/2021   ชาย       35.0           ปี
# 3         816993     12/8/2021     11/8/2021  หญิง       33.0           ปี
# 4         816994     12/8/2021     11/8/2021  หญิง       14.0           ปี
# ...          ...           ...           ...   ...        ...          ...
# 2409703  3226693     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 2409704  3226694     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 2409705  3226695     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 2409706  3226696     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 2409707  3226697     15/3/2022     14/3/2022  หญิง  36.943725  ไม่มีข้อมูล
#
#          nationality province_of_isolation  \
# ...

# %%
case_pro34 = case34.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
case_pro34
# Out:
#              No. announce_date Notified date   sex        age         Unit  \
# 0        1859158    26/10/2021    25/10/2021   ชาย       20.0           ปี
# 1        1859159    26/10/2021    25/10/2021  หญิง       42.0           ปี
# 2        1859160    26/10/2021    25/10/2021  หญิง       33.0           ปี
# 3        1859161    26/10/2021    25/10/2021  หญิง       52.0           ปี
# 4        1859162    26/10/2021    25/10/2021  หญิง       84.0           ปี
# ...          ...           ...           ...   ...        ...          ...
# 1367535  3226693     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 1367536  3226694     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 1367537  3226695     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 1367538  3226696     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 1367539  3226697     15/3/2022     14/3/2022  หญิง  36.943725  ไม่มีข้อมูล
#
#          nationality province_of_isolation  \
# ...

# %%
case_pro4 = case3.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province')
case_pro4
# Out:
#             No. announce_date Notified date   sex        age         Unit  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.000000           ปี
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.000000           ปี
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.000000           ปี
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.000000           ปี
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.000000           ปี
# ...         ...           ...           ...   ...        ...          ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357077  3226694     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357078  3226695     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357079  3226696     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 357080  3226697     15/3/2022     14/3/2022  หญิง  36.943725  ไม่มีข้อมูล
#
#         nationality province_of_isolation  \
# ...

# %% [markdown]
# case+province+lab

# %%
case_pro_lab4 = case_pro4.merge(lab_clean,how='left',left_on='province',right_on = 'province')
case_pro_lab4
# Out:
#              No. announce_date Notified date   sex        age         Unit  \
# 0        2869617     28/2/2022     27/2/2022   ชาย  41.000000           ปี
# 1        2869617     28/2/2022     27/2/2022   ชาย  41.000000           ปี
# 2        2869617     28/2/2022     27/2/2022   ชาย  41.000000           ปี
# 3        2869618     28/2/2022     27/2/2022  หญิง  45.000000           ปี
# 4        2869618     28/2/2022     27/2/2022  หญิง  45.000000           ปี
# ...          ...           ...           ...   ...        ...          ...
# 7183828  3226693     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 7183829  3226694     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 7183830  3226695     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 7183831  3226696     15/3/2022     14/3/2022   ชาย  36.943725  ไม่มีข้อมูล
# 7183832  3226697     15/3/2022     14/3/2022  หญิง  36.943725  ไม่มีข้อมูล
#
#          nationality province_of_isolation  \
# ...
